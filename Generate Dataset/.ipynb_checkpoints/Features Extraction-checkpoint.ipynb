# %%
from urllib.parse import urlparse,urlencode
import ipaddress
import re
from bs4 import BeautifulSoup
import whois
import urllib
import urllib.request
from datetime import datetime
import requests
import random
import pandas as pd
import csv
import ssl, socket

# %%
from urllib.parse import urlparse
urlparse('https://www.outdoorlife.com/complete-guide-to-using-fishing-sinkers/?utm_medium=social&%3Futm_source=facebook&fbclid=IwAR0H-iUyPTJZZptSKVQfQkKZyyc26yTViwtgThZCDjS4plurXKWUFInZik4')
# Out:
# ParseResult(scheme='https', netloc='www.outdoorlife.com', path='/complete-guide-to-using-fishing-sinkers/', params='', query='utm_medium=social&%3Futm_source=facebook&fbclid=IwAR0H-iUyPTJZZptSKVQfQkKZyyc26yTViwtgThZCDjS4plurXKWUFInZik4', fragment='')

# %%
urlparse('https://http://https://www.wikipedia.org/?https://title=https://File:https://Picoo.jpg')
# Out:
# ParseResult(scheme='https', netloc='http:', path='//https://www.wikipedia.org/', params='', query='https://title=https://File:https://Picoo.jpg', fragment='')

# %%
blacklist = [
    "https://phishingreel.io/api/v1/panels/today",
    "https://api.chongluadao.vn/v1/blacklist",
    "http://data.phishtank.com/data/online-valid.csv"
]

# %%
r = requests.get(blacklist[0])
r.json()
# Out:
# [{'uuid': '9a3878db-dba0-41f8-bf77-75c6ee7dec2b',
#   'detected': 1625064330,
#   'domain': 'amazon-signin-seorangcepu-175.duckdns.org',
#   'phish': {'panel_url': 'https://amazon-signin-seorangcepu-175.duckdns.org/admin/login.php',
#    'kit': '16Shop',
#    'emails': ['lerlah@yandex.com', 'admin@16shop.us']},
#   'host': {'ip': '34.106.76.10',
#    'asn': '15169',
#    'owner': 'GOOGLE, US',
#    'country': 'US'},
#   'certificate': {'issued': 1625064158,
#    'ca': 'R3',
#    'fingerprint': 'D6:DC:E0:2C:F2:BE:DC:35:5E:D3:75:43:8D:F8:98:3C:7C:2E:1D:63'}},
#  {'uuid': 'efec5fc9-931b-4807-92ea-bf4d3ce5e32d',
#   'detected': 1625060717,
#   'domain': 'amazon-signin-cepugaktaudiri-151.duckdns.org',
#   'phish': {'panel_url': 'https://amazon-signin-cepugaktaudiri-151.duckdns.org/admin/login.php',
#    'kit': '16Shop',
#    'emails': ['lerlah@yandex.com', 'admin@16shop.us']},
#   'host': {'ip': '34.106.76.10',
#    'asn': '15169',
#    'owner': 'GOOGLE, US',
#    'country': 'US'},
#   'certificate': {'issued': 1625060427,
#    'ca': 'R3',
#    'fingerprint': '90:EA:75:95:9B:CE:2E:A9:73:07:8D:D6:95:FC:4D:49:7F:F2:7B:4C'}},
#  {'uuid': '96de921f-c3fd-40ce-a923-21bae0af3d40',
#   'detected': 1625058633,
#   'domain': 'yahooreview.edgewaterdvm.com',
#   'phish': {'panel_url': 'https://yahooreview.edgewaterdvm.com/admin/index.php',
#    'kit': 'NHKit',
#    'emails': None},
#   'host': {'ip': '107.161.23.16',
#    'asn': '3842',
#    'owner': 'RAMNODE, US',
#    'country': 'US'},
#   'certificate': {'issued': 1625058303,
#    'ca': 'R3',
#    'fingerprint': '81:1E:49:50:4B:F4:2E:11:DE:B7:52:F0:E0:5F:77:F6:4E:9D:A8:33'}},
#  {'uuid': '1a45008d-8d6b-4b15-9808-0552b2b40b29',
#   'detected': 1625058368,
#   'domain': 'yahooreview.edgewaterdvm.com',
#   'phish': {'panel_url': 'https://yahooreview.edgewaterdvm.com/admin/index.php',
#    'kit': 'NHKit',
#    'emails': None},
#   'host': {'ip': '107.161.23.16',
#    'asn': '3842',
#    'owner': 'RAMNODE, US',
#    'country': 'US'},
#   'certificate': {'issued': 1625058300,
#    'ca': 'R3',
#    'fingerprint': 'FA:48:87:6B:F6:70:3E:99:D9:89:78:FA:AA:50:4F:DC:42:B1:80:78'}},
#  {'uuid': '373b07a5-c0b5-4193-a451-d9d8bcb6bd98',
#   'detected': 1625057764,
#   'domain': 'intli-srvcspaypal.duckdns.org',
#   'phish': {'panel_url': 'https://intli-srvcspaypal.duckdns.org/admin/login.php',
#    'kit': '16Shop',
#    'emails': None},
#   'host': {'ip': '23.99.179.156',
#    'asn': '8075',
#    'owner': 'MICROSOFT-CORP-MSN-AS-BLOCK, US',
#    'country': 'US'},
#   'certificate': {'issued': 1625057626,
#    'ca': 'R3',
#    'fingerprint': '2C:54:3F:A3:DE:32:7D:27:97:FB:5D:F6:6A:30:C8:1A:93:E1:E3:C5'}},
#  {'uuid': 'c7b5dbc5-b912-485c-85d9-6498bf340948',
#   'detected': 1625057221,
#   'domain': 'onedrive.ayby.xyz',
#   'phish': {'panel_url': 'https://onedrive.ayby.xyz/admin/index.php',
#    'kit': 'NHKit',
#    'emails': None},
#   'host': {'ip': '198.23.233.32',
#    'asn': '36352',
#    'owner': 'AS-COLOCROSSING, US',
#    'country': 'US'},
#   'certificate': {'issued': 1625057045,
#    'ca': 'R3',
#    'fingerprint': '29:D9:E5:B0:61:A0:D9:C9:B6:37:4A:4C:40:D4:18:CD:B5:DF:CB:A0'}},
#  {'uuid': '57293188-dd0a-4e96-9df7-2721980b12e8',
#   'detected': 1625057113,
#   'domain': 'amazon-signin-seorangcepu-175.duckdns.org',
#   'phish': {'panel_url': 'https://amazon-signin-seorangcepu-175.duckdns.org/admin/login.php',
#    'kit': '16Shop',
#    'emails': ['lerlah@yandex.com', 'admin@16shop.us']},
#   'host': {'ip': '34.106.76.10',
#    'asn': '15169',
#    'owner': 'GOOGLE, US',
#    'country': 'US'},
#   'certificate': {'issued': 1625056808,
#    'ca': 'R3',
#    'fingerprint': '0D:E1:EA:6D:18:14:BE:E8:EE:CB:CF:16:44:4B:DE:1F:76:96:02:2B'}},
#  {'uuid': '2c23a699-8166-4201-99b5-1e9386342b4f',
#   'detected': 1625056896,
#   'domain': 'amazon-signin-seorangcepu-175.duckdns.org',
#   'phish': {'panel_url': 'https://amazon-signin-seorangcepu-175.duckdns.org/admin/login.php',
#    'kit': '16Shop',
#    'emails': ['lerlah@yandex.com', 'admin@16shop.us']},
#   'host': {'ip': '34.106.76.10',
#    'asn': '15169',
#    'owner': 'GOOGLE, US',
#    'country': 'US'},
#   'certificate': {'issued': 1625056801,
#    'ca': 'R3',
#    'fingerprint': '66:F9:DE:4C:09:21:5C:CA:13:3B:10:2E:C1:A4:E7:E0:D5:4C:D6:81'}},
#  {'uuid': '285b5ebe-b1cb-4597-b40f-f4e387a81b90',
#   'detected': 1625055372,
#   'domain': 'account.locked.webbs-information.login.ucihasasule.com',
#   'phish': {'panel_url': 'https://account.locked.webbs-information.login.ucihasasule.com/admin/login.php',
#    'kit': '16Shop',
#    'emails': ['satebarokah@yandex.com', 'ys@youngsister.com']},
#   'host': {'ip': '192.163.198.71',
#    'asn': '46606',
#    'owner': 'UNIFIEDLAYER-AS-1, US',
#    'country': 'US'},
#   'certificate': {'issued': 1625055253,
#    'ca': 'R3',
#    'fingerprint': 'EA:34:20:55:16:72:A5:AF:B8:AA:3A:7D:02:06:CC:17:65:8F:6E:04'}},
#  {'uuid': '55d421cb-7f2c-4465-a0f6-65b234bd6e6f',
#   'detected': 1625055171,
#   'domain': 'sessionidmembership-amazon.faqserv.com',
#   'phish': {'panel_url': 'https://sessionidmembership-amazon.faqserv.com/admin/login.php',
#    'kit': 'FreakzBrothers',
#    'emails': None},
#   'host': {'ip': '143.198.41.74',
#    'asn': '14061',
#    'owner': 'DIGITALOCEAN-ASN, US',
#    'country': 'US'},
#   'certificate': {'issued': 1625054963,
#    'ca': 'cPanel, Inc. Certification Authority',
#    'fingerprint': '04:E3:2C:EC:66:04:64:D4:06:A8:64:5C:E9:B5:69:49:05:5D:69:06'}},
#  {'uuid': 'a411cf02-fcec-46ac-8a0e-da4646761bcb',
#   'detected': 1625054162,
#   'domain': 'recuritmenamazonservice.com',
#   'phish': {'panel_url': 'https://recuritmenamazonservice.com/admin/',
#    'kit': 'Antibot',
#    'emails': None},
#   'host': {'ip': '67.205.174.198',
#    'asn': '14061',
#    'owner': 'DIGITALOCEAN-ASN, US',
#    'country': 'US'},
#   'certificate': {'issued': 1625053977,
#    'ca': 'cPanel, Inc. Certification Authority',
#    'fingerprint': 'B2:C8:0F:72:51:B9:6E:6B:A2:B2:F3:CE:84:62:F7:61:83:AD:26:38'}},
#  {'uuid': '0db8b5d4-d597-443d-b71b-5bbf7a85d411',
#   'detected': 1625053536,
#   'domain': 'amazon-signin-seorangcepu-174.duckdns.org',
#   'phish': {'panel_url': 'https://amazon-signin-seorangcepu-174.duckdns.org/admin/login.php',
#    'kit': '16Shop',
#    'emails': ['lerlah@yandex.com', 'admin@16shop.us']},
#   'host': {'ip': '34.106.76.10',
#    'asn': '15169',
#    'owner': 'GOOGLE, US',
#    'country': 'US'},
#   'certificate': {'issued': 1625053290,
#    'ca': 'R3',
#    'fingerprint': '8D:DC:B4:17:4E:F6:34:90:95:7B:68:D2:A2:85:B2:67:C5:B6:C5:E0'}},
#  {'uuid': '1fa4d982-8933-48a8-a3d0-0d36de576c80',
#   'detected': 1625051455,
#   'domain': 'apple.com-id.maps-fmi.info',
#   'phish': {'panel_url': 'https://apple.com-id.maps-fmi.info/admin/auth.php',
#    'kit': 'iTech',
#    'emails': None},
#   'host': {'ip': '80.87.203.19',
#    'asn': '29182',
#    'owner': 'THEFIRST-AS, RU',
#    'country': 'RU'},
#   'certificate': {'issued': 1625051257,
#    'ca': 'R3',
#    'fingerprint': '08:5A:4C:D4:C5:00:71:80:7C:C9:9F:0F:36:4E:A0:75:F2:72:28:D0'}},
#  {'uuid': 'e2498dcc-fdae-4eae-b0f3-a6806990cc9c',
#   'detected': 1625051441,
#   'domain': 'icloud.com-id.maps-fmi.info',
#   'phish': {'panel_url': 'https://icloud.com-id.maps-fmi.info/admin/auth.php',
#    'kit': 'iTech',
#    'emails': None},
#   'host': {'ip': '80.87.203.19',
#    'asn': '29182',
#    'owner': 'THEFIRST-AS, RU',
#    'country': 'RU'},
#   'certificate': {'issued': 1625051257,
#    'ca': 'R3',
#    'fingerprint': '08:5A:4C:D4:C5:00:71:80:7C:C9:9F:0F:36:4E:A0:75:F2:72:28:D0'}},
#  {'uuid': 'feedf86a-17f3-466d-9a7d-9aaa7024b337',
#   'detected': 1625050511,
#   'domain': 'amazon-signin-seorangcepu-173.duckdns.org',
#   'phish': {'panel_url': 'https://amazon-signin-seorangcepu-173.duckdns.org/admin/login.php',
#    'kit': '16Shop',
#    'emails': ['lerlah@yandex.com', 'admin@16shop.us']},
#   'host': {'ip': '34.106.76.10',
#    'asn': '15169',
#    'owner': 'GOOGLE, US',
#    'country': 'US'},
#   'certificate': {'issued': 1625050313,
#    'ca': 'R3',
#    'fingerprint': '05:BF:B3:89:EE:20:55:10:78:1C:51:AB:7F:20:80:8E:04:1A:22:14'}},
#  {'uuid': '3164a541-3c82-4636-abd0-d75694ded4c1',
#   'detected': 1625049052,
#   'domain': 'vrf-paypalaccount.duckdns.org',
#   'phish': {'panel_url': 'https://vrf-paypalaccount.duckdns.org/admin/login.php',
#    'kit': '16Shop',
#    'emails': None},
#   'host': {'ip': '23.99.179.156',
#    'asn': '8075',
#    'owner': 'MICROSOFT-CORP-MSN-AS-BLOCK, US',
#    'country': 'US'},
#   'certificate': {'issued': 1625048947,
#    'ca': 'R3',
#    'fingerprint': '89:7C:55:DF:F6:00:93:6B:51:6B:41:9D:4D:C8:A1:8B:61:46:27:26'}},
#  {'uuid': '1e6e10e0-f2e6-46c1-8a6b-e22292c26617',
#   'detected': 1625047515,
#   'domain': 'mismacthbillingamazon.panel.cloudns.cl',
#   'phish': {'panel_url': 'https://mismacthbillingamazon.panel.cloudns.cl/admin/login.php',
#    'kit': '16Shop',
#    'emails': ['bullshitjoke@yandex.com', 'admin@takutterbawacinta.com']},
#   'host': {'ip': '20.55.66.180',
#    'asn': '8075',
#    'owner': 'MICROSOFT-CORP-MSN-AS-BLOCK, US',
#    'country': 'US'},
#   'certificate': {'issued': 1625047232,
#    'ca': 'cPanel, Inc. Certification Authority',
#    'fingerprint': '08:DE:56:54:08:F0:B2:93:C7:7E:96:F6:02:86:E7:27:B2:CC:6A:8D'}},
#  {'uuid': '532cc563-8719-4f88-88db-ab95bbf8bd70',
#   'detected': 1625047242,
#   'domain': 'amazon-signin-seorangcepu-172.duckdns.org',
#   'phish': {'panel_url': 'https://amazon-signin-seorangcepu-172.duckdns.org/admin/login.php',
#    'kit': '16Shop',
#    'emails': ['lerlah@yandex.com', 'admin@16shop.us']},
#   'host': {'ip': '34.106.76.10',
#    'asn': '15169',
#    'owner': 'GOOGLE, US',
#    'country': 'US'},
#   'certificate': {'issued': 1625046935,
#    'ca': 'R3',
#    'fingerprint': 'EF:88:6A:6B:11:97:33:09:79:28:75:40:5F:70:AE:26:EA:38:0C:C1'}},
#  {'uuid': '27d45b6a-aa57-4835-b754-42be5c51e440',
#   'detected': 1625044255,
#   'domain': 'amazon-signin-seorangcepu-171.duckdns.org',
#   'phish': {'panel_url': 'https://amazon-signin-seorangcepu-171.duckdns.org/admin/login.php',
#    'kit': '16Shop',
#    'emails': ['lerlah@yandex.com', 'admin@16shop.us']},
#   'host': {'ip': '34.106.76.10',
#    'asn': '15169',
#    'owner': 'GOOGLE, US',
#    'country': 'US'},
#   'certificate': {'issued': 1625044098,
#    'ca': 'R3',
#    'fingerprint': 'E7:9E:06:C3:8B:56:13:3D:09:6E:BE:C0:98:81:0C:17:90:B9:9F:7F'}},
#  {'uuid': 'e937128a-3645-40dd-93b7-88b347527c12',
#   'detected': 1625043351,
#   'domain': 'amazon-signin-seorangcepu-170.duckdns.org',
#   'phish': {'panel_url': 'https://amazon-signin-seorangcepu-170.duckdns.org/admin/login.php',
#    'kit': '16Shop',
#    'emails': ['lerlah@yandex.com', 'admin@16shop.us']},
#   'host': {'ip': '34.106.76.10',
#    'asn': '15169',
#    'owner': 'GOOGLE, US',
#    'country': 'US'},
#   'certificate': {'issued': 1625043146,
#    'ca': 'R3',
#    'fingerprint': '27:FF:EC:19:5A:9F:C5:70:06:24:10:B5:38:E1:F3:FF:DA:79:E6:47'}},
#  {'uuid': 'e5fdc581-1eaa-4521-bb52-199e2a09ab3f',
#   'detected': 1625043325,
#   'domain': 'verifysecurity.nl',
#   'phish': {'panel_url': 'https://piv.pivpiv.dk//',
#    'kit': 'iDiot',
#    'emails': None},
#   'host': {'ip': '149.210.209.83',
#    'asn': '20857',
#    'owner': 'TRANSIP-AS Amsterdam, the Netherlands, NL',
#    'country': 'NL'},
#   'certificate': {'issued': 1625043059,
#    'ca': 'R3',
#    'fingerprint': '20:01:42:35:75:A7:91:9F:03:FD:C0:5F:F5:95:19:46:EA:71:FF:9B'}},
#  {'uuid': 'db9b55e9-1734-455f-b182-c998607e4106',
#   'detected': 1625043104,
#   'domain': 'amazon-signin-seorangcepu-170.duckdns.org',
#   'phish': {'panel_url': 'https://amazon-signin-seorangcepu-170.duckdns.org/admin/login.php',
#    'kit': '16Shop',
#    'emails': ['lerlah@yandex.com', 'admin@16shop.us']},
#   'host': {'ip': '34.106.76.10',
#    'asn': '15169',
#    'owner': 'GOOGLE, US',
#    'country': 'US'},
#   'certificate': {'issued': 1625043000,
#    'ca': 'R3',
#    'fingerprint': '59:4F:E8:01:5F:2E:14:5D:37:9E:38:8F:8D:62:28:36:A0:71:88:8D'}},
#  {'uuid': '560dfd4b-cb8b-4cdb-a2a4-8e77013ff9d8',
#   'detected': 1625040980,
#   'domain': 'appleid-authloginsecuremcsrc.com.multitechsupplies.com',
#   'phish': {'panel_url': 'https://appleid-authloginsecuremcsrc.com.multitechsupplies.com/admin/',
#    'kit': 'iTech',
#    'emails': None},
#   'host': {'ip': '91.195.240.94',
#    'asn': '47846',
#    'owner': 'SEDO-AS, DE',
#    'country': 'DE'},
#   'certificate': {'issued': 1625040837,
#    'ca': 'Encryption Everywhere DV TLS CA - G1',
#    'fingerprint': '7B:7C:8A:13:2B:FC:35:0F:DE:B9:B5:DC:CD:83:F2:E2:E0:EB:32:A2'}},
#  {'uuid': '610c9433-b826-432c-a129-6678181c5089',
#   'detected': 1625038815,
#   'domain': 'amazonscureinfo.duckdns.org',
#   'phish': {'panel_url': 'https://amazonscureinfo.duckdns.org/admin/login.php',
#    'kit': 'FreakzBrothers',
#    'emails': None},
#   'host': {'ip': '20.98.65.65',
#    'asn': '8075',
#    'owner': 'MICROSOFT-CORP-MSN-AS-BLOCK, US',
#    'country': 'US'},
#   'certificate': {'issued': 1625038524,
#    'ca': 'R3',
#    'fingerprint': '04:8E:CE:E0:59:45:3C:43:4F:CF:C5:09:13:82:ED:C2:F3:30:4C:ED'}},
#  {'uuid': 'f848a23c-8a20-498c-9df5-3fcf92ab3aed',
#   'detected': 1625036112,
#   'domain': 'amazon-signin-seorangcepu-169.duckdns.org',
#   'phish': {'panel_url': 'https://amazon-signin-seorangcepu-169.duckdns.org/admin/login.php',
#    'kit': '16Shop',
#    'emails': ['lerlah@yandex.com', 'admin@16shop.us']},
#   'host': {'ip': '34.106.76.10',
#    'asn': '15169',
#    'owner': 'GOOGLE, US',
#    'country': 'US'},
#   'certificate': {'issued': 1625035880,
#    'ca': 'R3',
#    'fingerprint': '99:96:CA:BB:72:F9:CD:E4:57:8E:62:86:E2:34:56:B0:53:5F:CF:1F'}},
#  {'uuid': '688fae9d-52c6-4c0c-8e29-9b77280239c1',
#   'detected': 1625022320,
#   'domain': 'vn-icloud.com',
#   'phish': {'panel_url': 'https://vn-icloud.com/admin/',
#    'kit': 'YOURLS',
#    'emails': None},
#   'host': {'ip': '37.140.192.210',
#    'asn': '197695',
#    'owner': 'AS-REG, RU',
#    'country': 'RU'},
#   'certificate': {'issued': 1625022157,
#    'ca': 'R3',
#    'fingerprint': '70:79:24:01:11:B9:77:7A:A3:06:26:22:4D:D9:4B:D9:63:80:56:BB'}},
#  {'uuid': '450a8ff7-c7aa-4725-ac89-cbb1fef6ac93',
#   'detected': 1625022027,
#   'domain': 'www-iclouds.com',
#   'phish': {'panel_url': 'https://www-iclouds.com/admin/',
#    'kit': 'YOURLS',
#    'emails': None},
#   'host': {'ip': '104.21.46.75',
#    'asn': '13335',
#    'owner': 'CLOUDFLARENET, US',
#    'country': 'US'},
#   'certificate': {'issued': 1625021930,
#    'ca': 'R3',
#    'fingerprint': '4C:B4:DA:D4:AB:09:E3:6C:EE:BE:A2:9F:86:24:C4:8C:D6:69:E9:AC'}},
#  {'uuid': 'cec985cf-09bc-4470-902a-209175239263',
#   'detected': 1625013915,
#   'domain': 'manage-account-amazon-support-les2.com',
#   'phish': {'panel_url': 'https://manage-account-amazon-support-les2.com/admin/login.php',
#    'kit': '16Shop',
#    'emails': None},
#   'host': {'ip': '162.241.87.89',
#    'asn': '46606',
#    'owner': 'UNIFIEDLAYER-AS-1, US',
#    'country': 'US'},
#   'certificate': {'issued': 1625013715,
#    'ca': 'R3',
#    'fingerprint': 'D7:8F:25:BF:42:06:EC:6A:74:F0:EF:B2:72:46:94:57:82:DE:06:BE'}},
#  {'uuid': 'a2f62019-f0c8-4e17-bd77-0e00456002cc',
#   'detected': 1625011515,
#   'domain': 'primeidmember-amazon.zzux.com',
#   'phish': {'panel_url': 'https://primeidmember-amazon.zzux.com/admin/login.php',
#    'kit': 'FreakzBrothers',
#    'emails': None},
#   'host': {'ip': '143.198.41.74',
#    'asn': '14061',
#    'owner': 'DIGITALOCEAN-ASN, US',
#    'country': 'US'},
#   'certificate': {'issued': 1625011254,
#    'ca': 'cPanel, Inc. Certification Authority',
#    'fingerprint': '17:95:C9:40:62:C0:6A:E9:80:AE:C7:53:3E:21:4F:A3:7B:86:AB:02'}},
#  {'uuid': 'c13aaddc-0523-4236-adb2-f4ca76cc05de',
#   'detected': 1625011261,
#   'domain': 'primeidmember-amazon.zzux.com',
#   'phish': {'panel_url': 'https://primeidmember-amazon.zzux.com/admin/login.php',
#    'kit': 'FreakzBrothers',
#    'emails': None},
#   'host': {'ip': '143.198.41.74',
#    'asn': '14061',
#    'owner': 'DIGITALOCEAN-ASN, US',
#    'country': 'US'},
#   'certificate': {'issued': 1625011146,
#    'ca': 'cPanel, Inc. Certification Authority',
#    'fingerprint': '21:BF:9D:73:17:CE:7D:8B:23:0F:1E:39:40:5F:92:34:3D:E3:60:1F'}}]

# %%
n = 10
sample = random.sample(list(i['domain'] for i in r.json()), n)
sample
# Out:
# ['onedrive.ayby.xyz',
#  'vrf-paypalaccount.duckdns.org',
#  'amazon-signin-seorangcepu-170.duckdns.org',
#  'amazon-signin-seorangcepu-173.duckdns.org',
#  'amazon-signin-seorangcepu-172.duckdns.org',
#  'account.locked.webbs-information.login.ucihasasule.com',
#  'primeidmember-amazon.zzux.com',
#  'sessionidmembership-amazon.faqserv.com',
#  'yahooreview.edgewaterdvm.com',
#  'primeidmember-amazon.zzux.com']

# %%
phishtank = pd.read_csv("dataset/phishtankv2.csv")
with open('phishing.txt','w+',encoding='utf-8') as f:
    for i in phishtank['url']:
        f.write(i+'\n')

# %%
features = ['_id','url','type','level','meta']

with open('modify_dataset.csv', 'w') as csvfile:
    writer = csv.DictWriter(csvfile, fieldnames=features)
    writer.writeheader()
    writer.writerows(r.json())

# %%
# Virustotal URL Scanning
ca = set()

def extract_ca(domain):
    
#     hostname = whois.whois(urlparse(url).netloc)
    try:
        print(domain)
        hostname = domain
        ctx = ssl.create_default_context()
        with ctx.wrap_socket(socket.socket(), server_hostname=hostname) as s:
            s.settimeout(5)
            s.connect((hostname, 443))
            cert = s.getpeercert()

        subject = dict(x[0] for x in cert['subject'])
        issued_to = subject['commonName']
        issuer = dict(x[0] for x in cert['issuer'])
        issued_by = issuer['commonName']
        print(issued_by)

        ca.add(issued_by)
    except:
        print(f"DOMAIN {domain} ERROR")

# %%
top500 = pd.read_csv("dataset/top500Domains.csv")

# %%
for domain in top500["Root Domain"]:
    extract_ca(domain)
# Out:
# youtube.com
# GTS CA 1O1
# apple.com
# Apple Public EV Server ECC CA 1 - G1
# www.google.com
# GTS CA 1O1
# support.google.com
# GTS CA 1O1
# cloudflare.com
# Cloudflare Inc ECC CA-3
# www.blogger.com
# GTS CA 1O1
# play.google.com
# GTS CA 1O1
# microsoft.com
# Microsoft RSA TLS CA 01
# youtu.be
# GTS CA 1O1
# mozilla.org
# R3
# docs.google.com
# GTS CA 1O1
# en.wikipedia.org
# DigiCert SHA2 High Assurance Server CA
# wordpress.org
# Sectigo RSA Domain Validation Secure Server CA
# maps.google.com
# GTS CA 1O1
# linkedin.com
# DigiCert SHA2 Secure Server CA
# vimeo.com
# GlobalSign Atlas R3 DV TLS CA 2020
# europa.eu
# GlobalSign RSA OV SSL CA 2018
# plus.google.com
# GTS CA 1O1
# sites.google.com
# GTS CA 1O1
# adobe.com
# DigiCert SHA2 Secure Server CA
# accounts.google.com
# GTS CA 1O1
# googleusercontent.com
# DOMAIN googleusercontent.com ERROR
# drive.google.com
# GTS CA 1O1
# uol.com.br
# RapidSSL TLS DV RSA Mixed SHA256 2020 CA-1
# pt.wikipedia.org
# DigiCert SHA2 High Assurance Server CA
# bbc.co.uk
# GlobalSign RSA OV SSL CA 2018
# feedburner.com
# GTS CA 1O1
# line.me
# GlobalSign RSA OV SSL CA 2018
# bp.blogspot.com
# DOMAIN bp.blogspot.com ERROR
# cnn.com
# GlobalSign Atlas R3 DV TLS CA 2020
# facebook.com
# DigiCert SHA2 High Assurance Server CA
# github.com
# DigiCert High Assurance TLS Hybrid ECC SHA256 2020 CA1
# amazon.com
# DigiCert Global CA G2
# vk.com
# GlobalSign Organization Validation CA - SHA256 - G2
# es.wikipedia.org
# DigiCert SHA2 High Assurance Server CA
# istockphoto.com
# Amazon
# abril.com.br
# R3
# www.yahoo.com
# DigiCert SHA2 High Assurance Server CA
# creativecommons.org
# Cloudflare Inc ECC CA-3
# developers.google.com
# GTS CA 1O1
# policies.google.com
# GTS CA 1O1
# theguardian.com
# GlobalSign Atlas R3 DV TLS CA 2020
# google.de
# GTS CA 1O1
# google.es
# GTS CA 1O1
# myspace.com
# Go Daddy Secure Certificate Authority - G2
# dailymotion.com
# DigiCert SHA2 High Assurance Server CA
# gstatic.com
# GTS CA 1O1
# brandbucket.com
# Cloudflare Inc ECC CA-3
# reuters.com
# R3
# paypal.com
# DigiCert SHA2 High Assurance Server CA
# mail.ru
# GeoTrust RSA CA 2018
# forbes.com
# GlobalSign Atlas R3 DV TLS CA 2020
# nytimes.com
# Sectigo RSA Domain Validation Secure Server CA
# issuu.com
# Amazon
# nih.gov
# Go Daddy Secure Certificate Authority - G2
# medium.com
# DOMAIN medium.com ERROR
# www.weebly.com
# DigiCert SHA2 Secure Server CA
# slideshare.net
# Amazon
# t.me
# Go Daddy Secure Certificate Authority - G2
# w3.org
# Gandi Standard SSL CA 2
# mail.google.com
# GTS CA 1C3
# live.com
# DigiCert Cloud Services CA-1
# hugedomains.com
# Cloudflare Inc ECC CA-3
# msn.com
# Microsoft RSA TLS CA 02
# dropbox.com
# DigiCert SHA2 High Assurance Server CA
# whatsapp.com
# DigiCert SHA2 High Assurance Server CA
# get.google.com
# GTS CA 1O1
# jimdofree.com
# GlobalSign Atlas R3 DV TLS CA 2020
# globo.com
# R3
# opera.com
# DigiCert TLS Hybrid ECC SHA384 2020 CA1
# fr.wikipedia.org
# DigiCert SHA2 High Assurance Server CA
# google.co.jp
# GTS CA 1O1
# wikimedia.org
# DigiCert SHA2 High Assurance Server CA
# google.com.br
# GTS CA 1O1
# bbc.com
# DOMAIN bbc.com ERROR
# imdb.com
# Amazon
# news.google.com
# GTS CA 1O1
# translate.google.com
# GTS CA 1O1
# office.com
# DigiCert Cloud Services CA-1
# harvard.edu
# R3
# apache.org
# Sectigo RSA Domain Validation Secure Server CA
# amazon.co.uk
# DigiCert Global CA G2
# cpanel.com
# Sectigo RSA Domain Validation Secure Server CA
# cpanel.net
# Sectigo RSA Domain Validation Secure Server CA
# terra.com.br
# GlobalSign RSA OV SSL CA 2018
# foxnews.com
# DigiCert SHA2 Secure Server CA
# networkadvertising.org
# Amazon
# 4shared.com
# Go Daddy Secure Certificate Authority - G2
# archive.org
# Go Daddy Secure Certificate Authority - G2
# news.yahoo.com
# DigiCert SHA2 High Assurance Server CA
# cdc.gov
# Entrust Certification Authority - L1K
# youronlinechoices.com
# R3
# google.ru
# GTS CA 1O1
# wired.com
# GlobalSign Atlas R3 DV TLS CA 2020
# google.co.uk
# GTS CA 1O1
# businessinsider.com
# GlobalSign Atlas R3 DV TLS CA 2020
# bit.ly
# DOMAIN bit.ly ERROR
# myaccount.google.com
# GTS CA 1O1
# thesun.co.uk
# R3
# ig.com.br
# DOMAIN ig.com.br ERROR
# tinyurl.com
# Cloudflare Inc ECC CA-3
# steampowered.com
# R3
# latimes.com
# Amazon
# de.wikipedia.org
# DigiCert SHA2 High Assurance Server CA
# independent.co.uk
# GlobalSign Atlas R3 DV TLS CA 2020
# picasaweb.google.com
# GTS CA 1O1
# un.org
# COMODO RSA Organization Validation Secure Server CA
# booking.com
# DigiCert ECC Secure Server CA
# hatena.ne.jp
# Amazon
# www.gov.uk
# GlobalSign RSA OV SSL CA 2018
# aol.com
# DigiCert SHA2 High Assurance Server CA
# aliexpress.com
# GlobalSign Organization Validation CA - SHA256 - G2
# photos.google.com
# GTS CA 1O1
# twitter.com
# DigiCert TLS RSA SHA256 2020 CA1
# telegraph.co.uk
# Amazon
# pinterest.com
# DigiCert SHA2 High Assurance Server CA
# google.pl
# GTS CA 1O1
# books.google.com
# GTS CA 1O1
# change.org
# DOMAIN change.org ERROR
# samsung.com
# Sectigo RSA Organization Validation Secure Server CA
# search.google.com
# GTS CA 1O1
# usatoday.com
# R3
# scribd.com
# R3
# amazon.de
# DigiCert Global CA G2
# android.com
# GTS CA 1O1
# wikia.com
# GlobalSign Atlas R3 DV TLS CA 2020
# fb.com
# DigiCert SHA2 High Assurance Server CA
# ok.ru
# GeoTrust RSA CA 2018
# bloomberg.com
# DigiCert SHA2 Extended Validation Server CA
# ebay.com
# Sectigo RSA Organization Validation Secure Server CA
# google.fr
# GTS CA 1O1
# dailymail.co.uk
# DigiCert SHA2 Secure Server CA
# dan.com
# R3
# telegram.me
# Go Daddy Secure Certificate Authority - G2
# wsj.com
# Amazon
# buydomains.com
# Sectigo RSA Domain Validation Secure Server CA
# tools.google.com
# GTS CA 1O1
# huffingtonpost.com
# Amazon
# it.wikipedia.org
# DigiCert SHA2 High Assurance Server CA
# google.it
# GTS CA 1O1
# amazon.co.jp
# DigiCert Global CA G2
# elpais.com
# R3
# who.int
# Cloudflare Inc ECC CA-3
# rakuten.co.jp
# DigiCert SHA2 Secure Server CA
# wa.me
# DigiCert SHA2 High Assurance Server CA
# time.com
# Amazon
# cnet.com
# DigiCert SHA2 High Assurance Server CA
# namecheap.com
# Sectigo RSA Extended Validation Secure Server CA
# goo.gl
# GTS CA 1O1
# plesk.com
# Sectigo RSA Domain Validation Secure Server CA
# aboutads.info
# Amazon
# fandom.com
# GlobalSign Atlas R3 DV TLS CA 2020
# mediafire.com
# Sectigo RSA Domain Validation Secure Server CA
# id.wikipedia.org
# DigiCert SHA2 High Assurance Server CA
# gravatar.com
# Sectigo RSA Domain Validation Secure Server CA
# nasa.gov
# Entrust Certification Authority - L1K
# files.wordpress.com
# Sectigo RSA Domain Validation Secure Server CA
# huffpost.com
# Amazon
# washingtonpost.com
# Entrust Certification Authority - L1M
# draft.blogger.com
# GTS CA 1O1
# abcnews.go.com
# Amazon
# marketingplatform.google.com
# GTS CA 1O1
# pbs.org
# R3
# urbandictionary.com
# GlobalSign Atlas R3 DV TLS CA 2020
# buzzfeed.com
# Amazon
# www.wikipedia.org
# DigiCert SHA2 High Assurance Server CA
# google.ca
# GTS CA 1O1
# cambridge.org
# DOMAIN cambridge.org ERROR
# walmart.com
# GlobalSign RSA OV SSL CA 2018
# naver.com
# DigiCert SHA2 Secure Server CA
# ign.com
# GlobalSign Atlas R3 DV TLS CA 2020
# abc.net.au
# DigiCert TLS RSA SHA256 2020 CA1
# bloglovin.com
# DOMAIN bloglovin.com ERROR
# detik.com
# Thawte RSA CA 2018
# allaboutcookies.org
# Cloudflare Inc ECC CA-3
# ea.com
# DigiCert SHA2 Secure Server CA
# britannica.com
# Amazon
# spotify.com
# DigiCert TLS RSA SHA256 2020 CA1
# ibm.com
# DigiCert SHA2 Secure Server CA
# ikea.com
# DOMAIN ikea.com ERROR
# cbc.ca
# DigiCert SHA2 Secure Server CA
# qq.com
# Secure Site CA G2
# mirror.co.uk
# Amazon
# fda.gov
# DOMAIN fda.gov ERROR
# techcrunch.com
# DigiCert SHA2 High Assurance Server CA
# icann.org
# DigiCert TLS RSA SHA256 2020 CA1
# lycos.com
# R3
# enable-javascript.com
# RapidSSL TLS DV RSA Mixed SHA256 2020 CA-1
# nginx.com
# R3
# newsweek.com
# Amazon
# lemonde.fr
# GlobalSign Atlas R3 DV TLS CA 2020
# ovh.net
# DOMAIN ovh.net ERROR
# clickbank.net
# DOMAIN clickbank.net ERROR
# ziddu.com
# R3
# sfgate.com
# R3
# sedo.com
# GeoTrust TLS RSA CA G1
# indiatimes.com
# DigiCert Secure Site ECC CA-1
# biglobe.ne.jp
# GeoTrust RSA CA 2018
# engadget.com
# DigiCert SHA2 High Assurance Server CA
# imageshack.us
# Go Daddy Secure Certificate Authority - G2
# trustpilot.com
# Amazon
# hm.com
# DigiCert SHA2 Secure Server CA
# google.com.tw
# GTS CA 1O1
# doubleclick.net
# GTS CA 1O1
# economist.com
# Cloudflare Inc ECC CA-3
# ca.gov
# Sectigo RSA Organization Validation Secure Server CA
# bandcamp.com
# GlobalSign Atlas R3 DV TLS CA 2020
# yahoo.co.jp
# Cybertrust Japan SureServer CA G4
# google.co.in
# GTS CA 1O1
# wiley.com
# DigiCert TLS RSA SHA256 2020 CA1
# yadi.sk
# Yandex CA
# list-manage.com
# DOMAIN list-manage.com ERROR
# shutterstock.com
# Amazon
# rt.com
# GeoTrust RSA CA 2018
# nikkei.com
# Amazon
# sapo.pt
# Sectigo RSA Organization Validation Secure Server CA
# thetimes.co.uk
# R3
# forms.gle
# GTS CA 1D4
# my.yahoo.com
# DigiCert SHA2 High Assurance Server CA
# photobucket.com
# Amazon
# gmail.com
# GTS CA 1O1
# google.co.id
# GTS CA 1O1
# www.over-blog.com
# R3
# newyorker.com
# GlobalSign Atlas R3 DV TLS CA 2020
# addthis.com
# DOMAIN addthis.com ERROR
# nature.com
# R3
# ted.com
# R3
# netvibes.com
# Sectigo RSA Domain Validation Secure Server CA
# cnbc.com
# Entrust Certification Authority - L1K
# umich.edu
# InCommon RSA Server CA
# godaddy.com
# DOMAIN godaddy.com ERROR
# bund.de
# DFN-Verein Global Issuing CA
# huawei.com
# DOMAIN huawei.com ERROR
# ru.wikipedia.org
# DigiCert SHA2 High Assurance Server CA
# repubblica.it
# Amazon
# noaa.gov
# DOMAIN noaa.gov ERROR
# mozilla.com
# R3
# adssettings.google.com
# GTS CA 1O1
# mashable.com
# Cloudflare Inc ECC CA-3
# mysql.com
# DigiCert TLS RSA SHA256 2020 CA1
# espn.com
# Entrust Certification Authority - L1K
# rottentomatoes.com
# COMODO RSA Organization Validation Secure Server CA
# news.com.au
# DigiCert SHA2 Secure Server CA
# sciencedirect.com
# Cloudflare Inc ECC CA-3
# orange.fr
# DigiCert TLS RSA SHA256 2020 CA1
# sendspace.com
# Cloudflare Inc ECC CA-3
# disqus.com
# DOMAIN disqus.com ERROR
# nypost.com
# R3
# surveymonkey.com
# Amazon
# nginx.org
# R3
# loc.gov
# Entrust Certification Authority - L1K
# elmundo.es
# AlphaSSL CA - SHA256 - G2
# secureserver.net
# Starfield Secure Certificate Authority - G2
# hp.com
# DOMAIN hp.com ERROR
# ietf.org
# Starfield Secure Certificate Authority - G2
# google.nl
# GTS CA 1O1
# m.wikipedia.org
# DigiCert SHA2 High Assurance Server CA
# php.net
# Certum Domain Validation CA SHA2
# washington.edu
# InCommon RSA Server CA
# weibo.com
# GeoTrust CN RSA CA G1
# finance.yahoo.com
# DigiCert SHA2 High Assurance Server CA
# researchgate.net
# AlphaSSL CA - SHA256 - G2
# e-monsite.com
# Cloudflare Inc ECC CA-3
# nbcnews.com
# Entrust Certification Authority - L1K
# smh.com.au
# Amazon
# chicagotribune.com
# DOMAIN chicagotribune.com ERROR
# gizmodo.com
# GlobalSign Atlas R3 DV TLS CA 2020
# whitehouse.gov
# GeoTrust RSA CA 2018
# storage.googleapis.com
# GTS CA 1O1
# netflix.com
# DigiCert SHA2 Secure Server CA
# depositfiles.com
# Sectigo RSA Domain Validation Secure Server CA
# academia.edu
# Sectigo RSA Domain Validation Secure Server CA
# instagram.com
# DigiCert SHA2 High Assurance Server CA
# sciencedaily.com
# Amazon
# quora.com
# R3
# discord.com
# Cloudflare Inc ECC CA-3
# mit.edu
# GeoTrust RSA CA 2018
# nationalgeographic.com
# Amazon
# t.co
# DigiCert TLS RSA SHA256 2020 CA1
# guardian.co.uk
# GlobalSign Atlas R3 DV TLS CA 2020
# imageshack.com
# Go Daddy Secure Certificate Authority - G2
# amazon.es
# Amazon
# themeforest.net
# Cloudflare Inc ECC CA-3
# nydailynews.com
# DOMAIN nydailynews.com ERROR
# ria.ru
# RU-CENTER High Assurance Services CA 2
# shopify.com
# R3
# webmd.com
# R3
# ovh.co.uk
# Sectigo RSA Domain Validation Secure Server CA
# ipv4.google.com
# GTS CA 1O1
# picasa.google.com
# GTS CA 1O1
# instructables.com
# DigiCert SHA2 Extended Validation Server CA
# sputniknews.com
# RU-CENTER High Assurance Services CA 2
# lefigaro.fr
# DigiCert SHA2 Secure Server CA
# soundcloud.com
# GlobalSign GCC R3 DV TLS CA 2020
# sciencemag.org
# Amazon
# akamaihd.net
# DOMAIN akamaihd.net ERROR
# gnu.org
# R3
# metro.co.uk
# R3
# cbsnews.com
# Sectigo RSA Organization Validation Secure Server CA
# usnews.com
# Network Solutions OV Server CA 2
# www.wix.com
# Sectigo RSA Domain Validation Secure Server CA
# oup.com
# DigiCert SHA2 High Assurance Server CA
# npr.org
# Thawte RSA CA 2018
# bitly.com
# DigiCert TLS RSA SHA256 2020 CA1
# rapidshare.com
# DOMAIN rapidshare.com ERROR
# mega.nz
# R3
# berkeley.edu
# InCommon RSA Server CA
# nokia.com
# DigiCert Global CA G2
# abc.es
# DigiCert SHA2 Secure Server CA
# theverge.com
# GlobalSign Atlas R3 DV TLS CA 2020
# privacyshield.gov
# DOMAIN privacyshield.gov ERROR
# ytimg.com
# DOMAIN ytimg.com ERROR
# groups.google.com
# GTS CA 1O1
# alibaba.com
# GlobalSign Organization Validation CA - SHA256 - G2
# about.com
# R3
# wp.com
# Sectigo RSA Domain Validation Secure Server CA
# ggpht.com
# DOMAIN ggpht.com ERROR
# tripadvisor.com
# GlobalSign RSA OV SSL CA 2018
# columbia.edu
# InCommon RSA Server CA
# twitch.tv
# GlobalSign Atlas R3 DV TLS CA 2020
# playstation.com
# DigiCert TLS RSA SHA256 2020 CA1
# oracle.com
# DigiCert TLS RSA SHA256 2020 CA1
# arxiv.org
# InCommon RSA Server CA
# asus.com
# DOMAIN asus.com ERROR
# code.google.com
# GTS CA 1O1
# digg.com
# Cloudflare Inc ECC CA-3
# yelp.com
# DigiCert TLS RSA SHA256 2020 CA1
# bing.com
# Microsoft RSA TLS CA 01
# amazon.fr
# Amazon
# ovh.com
# Sectigo RSA Domain Validation Secure Server CA
# goodreads.com
# Amazon
# search.yahoo.com
# DigiCert SHA2 High Assurance Server CA
# alexa.com
# Amazon
# deezer.com
# Gandi Pro SSL CA 2
# discord.gg
# Cloudflare Inc ECC CA-3
# addtoany.com
# Cloudflare Inc ECC CA-3
# rambler.ru
# RapidSSL TLS DV RSA Mixed SHA256 2020 CA-1
# spiegel.de
# Sectigo RSA Domain Validation Secure Server CA
# ft.com
# GlobalSign Atlas R3 DV TLS CA 2020
# pixabay.com
# Cloudflare Inc ECC CA-3
# variety.com
# R3
# stanford.edu
# InCommon RSA Server CA
# unesco.org
# DOMAIN unesco.org ERROR
# box.com
# GeoTrust RSA CA 2018
# wikihow.com
# R3
# afternic.com
# Go Daddy Secure Certificate Authority - G2
# eventbrite.com
# DigiCert SHA2 High Assurance Server CA
# googleblog.com
# GTS CA 1O1
# pl.wikipedia.org
# DigiCert SHA2 High Assurance Server CA
# disney.com
# Entrust Certification Authority - L1K
# dw.com
# Thawte RSA CA 2018
# xbox.com
# Microsoft RSA TLS CA 02
# welt.de
# GeoTrust TLS RSA CA G1
# express.co.uk
# Amazon
# ja.wikipedia.org
# DigiCert SHA2 High Assurance Server CA
# gofundme.com
# DOMAIN gofundme.com ERROR
# kickstarter.com
# GlobalSign Atlas R3 DV TLS CA 2020
# theatlantic.com
# DigiCert TLS RSA SHA256 2020 CA1
# cornell.edu
# InCommon RSA Server CA
# zendesk.com
# Sectigo RSA Domain Validation Secure Server CA
# yandex.ru
# Yandex CA
# psychologytoday.com
# Amazon
# stackoverflow.com
# R3
# psu.edu
# InCommon RSA Server CA
# sky.com
# Sectigo RSA Organization Validation Secure Server CA
# sina.com.cn
# GeoTrust CN RSA CA G1
# utexas.edu
# R3
# skype.com
# Microsoft RSA TLS CA 02
# calendar.google.com
# GTS CA 1O1
# usc.edu
# InCommon RSA Server CA
# tes.com
# DigiCert SHA2 High Assurance Server CA
# canva.com
# Cloudflare Inc ECC CA-3
# vkontakte.ru
# GlobalSign Organization Validation CA - SHA256 - G2
# newscientist.com
# GlobalSign Atlas R3 DV TLS CA 2020
# worldbank.org
# COMODO RSA Extended Validation Secure Server CA
# scientificamerican.com
# Amazon
# bp1.blogger.com
# GTS CA 1O1
# undeveloped.com
# R3
# fortune.com
# Amazon
# parallels.com
# Sectigo RSA Domain Validation Secure Server CA
# mixcloud.com
# Cloudflare Inc ECC CA-3
# thefreedictionary.com
# Sectigo RSA Domain Validation Secure Server CA
# indianexpress.com
# DigiCert SHA2 Secure Server CA
# cisco.com
# HydrantID SSL CA G3
# marriott.com
# Entrust Certification Authority - L1K
# sony.com
# Sectigo RSA Organization Validation Secure Server CA
# histats.com
# R3
# offset.com
# Amazon
# adweek.com
# R3
# theglobeandmail.com
# DigiCert TLS RSA SHA256 2020 CA1
# steamcommunity.com
# DigiCert SHA2 Extended Validation Server CA
# about.me
# Cloudflare Inc ECC CA-3
# qz.com
# GlobalSign Atlas R3 DV TLS CA 2020
# ucla.edu
# InCommon RSA Server CA
# snapchat.com
# DigiCert SHA2 Secure Server CA
# zeit.de
# R3
# cafepress.com
# Amazon
# ieee.org
# GlobalSign RSA OV SSL CA 2018
# fastcompany.com
# GlobalSign Atlas R3 DV TLS CA 2020
# merriam-webster.com
# Amazon
# ucoz.ru
# R3
# blog.fc2.com
# RapidSSL RSA CA 2018
# ubuntu.com
# R3
# dreniq.com
# cPanel, Inc. Certification Authority
# espn.go.com
# Entrust Certification Authority - L1K
# pexels.com
# Cloudflare Inc ECC CA-3
# etsy.com
# GlobalSign Atlas R3 DV TLS CA 2020
# dot.tk
# DOMAIN dot.tk ERROR
# hbr.org
# DigiCert TLS RSA SHA256 2020 CA1
# naver.jp
# GlobalSign RSA OV SSL CA 2018
# feedproxy.google.com
# GTS CA 1O1
# freepik.com
# R3
# tmz.com
# Amazon
# techradar.com
# R3
# windows.net
# DOMAIN windows.net ERROR
# standard.co.uk
# GlobalSign Atlas R3 DV TLS CA 2020
# indiegogo.com
# DigiCert SHA2 Secure Server CA
# billboard.com
# Cloudflare Inc ECC CA-3
# home.neustar
# DOMAIN home.neustar ERROR
# thoughtco.com
# R3
# dictionary.com
# R3
# goo.ne.jp
# Cybertrust Japan SureServer EV CA G3
# eff.org
# R3
# 20minutos.es
# Thawte RSA CA 2018
# gutenberg.org
# Network Solutions OV Server CA 2
# fb.me
# DigiCert SHA2 High Assurance Server CA
# wn.com
# Sectigo RSA Domain Validation Secure Server CA
# sports.yahoo.com
# DigiCert SHA2 High Assurance Server CA
# imgur.com
# DigiCert SHA2 Secure Server CA
# xinhuanet.com
# DOMAIN xinhuanet.com ERROR
# slate.com
# R3
# outlook.com
# DigiCert Cloud Services CA-1
# daum.net
# Thawte TLS RSA CA G1
# livescience.com
# R3
# storage.canalblog.com
# Gandi Standard SSL CA 2
# yale.edu
# R3
# redhat.com
# DigiCert SHA2 High Assurance Server CA
# pcmag.com
# Cloudflare Inc ECC CA-3
# rediff.com
# DigiCert SHA2 High Assurance Server CA
# www.livejournal.com
# RapidSSL TLS DV RSA Mixed SHA256 2020 CA-1
# nvidia.com
# DigiCert TLS RSA SHA256 2020 CA1
# narod.ru
# GoGetSSL RSA DV CA
# iso.org
# Thawte EV RSA CA 2018
# jstor.org
# GlobalSign Organization Validated CA - SHA256 - G4
# kinja.com
# GlobalSign Atlas R3 DV TLS CA 2020
# thestar.com
# Trustwave Organization Validation SHA256 CA, Level 1
# viglink.com
# Amazon
# usgs.gov
# DigiCert SHA2 High Assurance Server CA
# princeton.edu
# InCommon RSA Server CA
# kotaku.com
# GlobalSign Atlas R3 DV TLS CA 2020
# elsevier.com
# Trustwave Organization Validation SHA256 CA, Level 1
# thenextweb.com
# Cloudflare Inc ECC CA-3
# amazon.ca
# Amazon
# ed.gov
# Sectigo RSA Domain Validation Secure Server CA
# symantec.com
# DigiCert Global G2 TLS RSA SHA256 2020 CA1
# wisc.edu
# COMODO RSA Extended Validation Secure Server CA
# venturebeat.com
# R3
# insider.com
# GlobalSign Atlas R3 DV TLS CA 2020
# interia.pl
# DigiCert TLS RSA SHA256 2020 CA1
# blackberry.com
# DigiCert SHA2 Secure Server CA
# orkut.com.br
# DOMAIN orkut.com.br ERROR
# prestashop.com
# Go Daddy Secure Certificate Authority - G2
# fifa.com
# DigiCert TLS RSA SHA256 2020 CA1
# sakura.ne.jp
# DOMAIN sakura.ne.jp ERROR
# cia.gov
# DigiCert SHA2 Extended Validation Server CA
# en.wordpress.com
# Sectigo RSA Domain Validation Secure Server CA
# video.google.com
# GTS CA 1O1
# arstechnica.com
# Amazon
# e-recht24.de
# Starfield Secure Certificate Authority - G2
# gooyaabitemplates.com
# cPanel, Inc. Certification Authority
# ebay.co.uk
# Sectigo RSA Organization Validation Secure Server CA
# yandex.com
# Yandex CA
# pastebin.com
# Cloudflare Inc ECC CA-3
# debian.org
# R3
# timeout.com
# Amazon
# calameo.com
# Gandi Standard SSL CA 2
# go.co
# DOMAIN go.co ERROR
# politico.com
# DigiCert TLS RSA SHA256 2020 CA1
# lifehacker.com
# GlobalSign Atlas R3 DV TLS CA 2020
# allrecipes.com
# Amazon
# scoop.it
# Sectigo RSA Domain Validation Secure Server CA
# coursera.org
# Amazon
# teamviewer.com
# RapidSSL RSA CA 2018
# answers.yahoo.com
# DigiCert SHA2 High Assurance Server CA
# digitaltrends.com
# R3
# cam.ac.uk
# QuoVadis Europe EV SSL CA G1
# businesswire.com
# DigiCert SHA2 Secure Server CA
# soratemplates.com
# GTS CA 1D4
# asahi.com
# DigiCert Secure Site ECC CA-1
# evernote.com
# DigiCert SHA2 Secure Server CA
# prnewswire.com
# DigiCert SHA2 High Assurance Server CA
# entrepreneur.com
# GlobalSign Atlas R3 DV TLS CA 2020
# answers.com
# GlobalSign Atlas R3 DV TLS CA 2020
# photos1.blogger.com
# GTS CA 1O1
# tabelog.com
# DigiCert TLS RSA SHA256 2020 CA1
# archives.gov
# Entrust Certification Authority - L1K
# feedburner.google.com
# GTS CA 1O1
# nps.gov
# Go Daddy Secure Certificate Authority - G2
# nicovideo.jp
# GlobalSign RSA OV SSL CA 2018
# megaupload.com
# DOMAIN megaupload.com ERROR

# %%
ca = set([i.split(" ")[0] for i in list(ca)])
list(ca
# Out:
# {'AlphaSSL',
#  'Amazon',
#  'Apple',
#  'COMODO',
#  'Certum',
#  'Cloudflare',
#  'Cybertrust',
#  'DFN-Verein',
#  'DigiCert',
#  'Entrust',
#  'GTS',
#  'Gandi',
#  'GeoTrust',
#  'GlobalSign',
#  'Go',
#  'GoGetSSL',
#  'HydrantID',
#  'InCommon',
#  'Microsoft',
#  'Network',
#  'QuoVadis',
#  'R3',
#  'RU-CENTER',
#  'RapidSSL',
#  'Sectigo',
#  'Secure',
#  'Starfield',
#  'Thawte',
#  'Trustwave',
#  'Yandex',
#  'cPanel,'}

# %%
list(ca)
# Out:
# ['cPanel,',
#  'Microsoft',
#  'HydrantID',
#  'AlphaSSL',
#  'GTS',
#  'RapidSSL',
#  'DFN-Verein',
#  'Cloudflare',
#  'GeoTrust',
#  'QuoVadis',
#  'Certum',
#  'Amazon',
#  'Gandi',
#  'COMODO',
#  'Go',
#  'Cybertrust',
#  'GlobalSign',
#  'Yandex',
#  'R3',
#  'Network',
#  'DigiCert',
#  'GoGetSSL',
#  'Thawte',
#  'Apple',
#  'Starfield',
#  'RU-CENTER',
#  'Trustwave',
#  'Entrust',
#  'InCommon',
#  'Sectigo',
#  'Secure']

# %% [markdown]
# ### Different port

# %%
def diff_port(url):
    p = '(?:http.*://)?(?P<host>[^:/ ]+).?(?P<port>[0-9]*).*'

    m = re.search(p,url)
    if m.group('port') :
        return 1
    else :
        return 0
diff_port('http://www.abc.com:123/test')
# Out:
# 1

# %% [markdown]
# ### Google Search

# %%
def top_n_google(domain, stop=30):
    try:
        from googlesearch import search
    except ImportError: 
        print("No module named 'google' found")
    google_search = [j for j in search(domain, tld="co.in", num=10, stop=stop, pause=2)]
    if 'domain' not in  google_search:
            return 1
    else:
        return 0

# %% [markdown]
# ### Punnycode
# references: https://stackoverflow.com/questions/14313849/how-to-validate-internationalized-domain-names

# %%
def punny(iri):
    if isinstance(iri, str):
        (scheme, netloc, path, query, fragment) = urlsplit(iri)
        scheme = quote(scheme)
        netloc = netloc.encode('idna').decode('utf-8')
        print(netloc)
        if 'xn--' in netloc:
            return 1
        else :
            return 0
    
punny("http://pfarmerü.com")
# Out:
# xn--pfarmer-t2a.com
# 1

# %% [markdown]
# <b>or

# %%
punny_url = "http://pfarmerü.com"
vaild_regex = "/^(http|https|ftp):\/\/([A-Z0-9][A-Z0-9_-]*(?:\.[A-Z0-9][A-Z0-9_-]*)+):?(\d+)?\/?/i"
if re.match(vaild_regex,punny_url):
    print('OK')
else:
    print("INVALID")
# Out:
# INVALID

# %%
domain = re.findall(r"://([^/]+)/?", url)[0]
if re.match(r"^www.", domain):
    domain = domain.replace("www.", "")
whois_response = whois.whois(domain)

# %%
domain
# Out:
# 'github.com'

# %% [markdown]
# ### page rank

# %%
domain = re.findall(r"://([^/]+)/?", url)[0]
if re.match(r"^www.", domain):
    domain = domain.replace("www.", "")
whois_response = whois.whois(domain)

payload={"name": domain }

rank_checker_response = requests.get("https://www.checkpagerank.net/index.php", data=payload)
try:
    global_rank = int(re.findall(
        r"Global Rank: ([0-9]+)", rank_checker_response.text)[0])
except:
    global_rank = -1

# %%
rank_checker_response = requests.get("https://www.checkpagerank.net/index.php", data=payload)

# %%
int(re.findall(r"Global Rank: ([0-9]+)", rank_checker_response.text)[0])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-20-ad25bb18ac7e> in <module>
# ----> 1 int(re.findall(r"Global Rank: ([0-9]+)", rank_checker_response.text)[0])
#
# IndexError: list index out of range

# %% [markdown]
# ## Favicon

# %% [markdown]
# <i>If the favicon not belong to the domain then it's phishing

# %%
import favicon 
def favicon(url):
    domain = re.findall(r"://([^/]+)/?", url)[0]
    
    icons = favicon.get(url)
    verify_icon 
    
    for _ in range(len(icons)):
        if domain not in icons[_].url:
            return 1 
        else :
            return 0

# %% [markdown]
# ## Validate domain and subdomain

# %%
url = 'https://github.com/'
val = "/^([a-z]+\:\/{2})?([\w-]+\.[\w-]+\.\w+)$/"

print(re.match(val, url))
# Out:
# None

# %%
def mouseOver(response): 
        if response == "" :
            return 1
        else:
            if re.findall("<script>.+onmouseover.+</script>", response.text):
                return 1
            else:
                return 0
    
    # 17.Checks the status of the right click attribute (Right_Click)
def rightClick(response):
    if response == "":
        return 1
    else:
        if re.findall(r"event.button ?== ?2", response.text):
            return 0
        else:
            return 1
